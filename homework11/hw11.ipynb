# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
def orbital_period(a):
    return (a ** 3)

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
# Given values
planet_a = 0.5
planet_b = 1.0
planet_c = 1.5

# Calculating orbital period
def orbital_period(a):
    return (a ** 3) ** 0.5

# Print
print("Orbital period of planet_a:", orbital_period(planet_a))
print("Orbital period of planet_b:", orbital_period(planet_b))
print("Orbital period of planet_c:", orbital_period(planet_c))
# Out:
# Orbital period of planet_a: 0.3535533905932738
# Orbital period of planet_b: 1.0
# Orbital period of planet_c: 1.8371173070873836

# %% [markdown]
# Import `numpy` in the cell below.

# %%
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# In a notebook, you only need to call it once, and it remains active throughout. Resetting the kernel would remove it.

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
def orbital_period(a):
    return np.sqrt(a ** 3)

# Semi-major axes
planet_a = 0.5
planet_b = 1.0
planet_c = 1.5

# Print
print("Orbital period of planet_a:", orbital_period(planet_a))
print("Orbital period of planet_b:", orbital_period(planet_b))
print("Orbital period of planet_c:", orbital_period(planet_c))
# Out:
# Orbital period of planet_a: 0.3535533905932738
# Orbital period of planet_b: 1.0
# Orbital period of planet_c: 1.8371173070873836

# %% [markdown]
# Import the `time` package in the cell below.

# %%
# Your code here
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
import time
import numpy as np

# Function w/ NumPy
def orbital_period_numpy(a):
    return np.sqrt(a ** 3)

# Function w/o NumPy
def orbital_period_original(a):
    return (a ** 3) ** 0.5
# Given a 
a = 5

# Timing the NumPy function
start_time = time.time()
orbital_period_numpy(a)
end_time = time.time()
print("NumPy function time:", end_time - start_time, "seconds")

# Timing the original function
start_time = time.time()
orbital_period_basic(a)
end_time = time.time()
print("Original function time:", end_time - start_time, "seconds")
# Out:
# NumPy function time: 0.0002307891845703125 seconds
# Original function time: 3.266334533691406e-05 seconds

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# The original function is faster because NumPy adds extra steps for simple tasks. But NumPy works much better when doing bigger or more complicated calculations.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1,000,000 semi-major axis values.

# %%
# List with 1,000,000 semi-major axis values
semi_major_axes = [i * 0.1 for i in range(1, 1000001)]

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
import time
import numpy as np

# Function w/ NumPy
def orbital_period_numpy(a):
    return np.sqrt(a ** 3)

# Function w/o NumPy
def orbital_period_original(a):
    return (a ** 3) ** 0.5
    
# Given a 
a = 5

# Timing the NumPy function
start_time = time.time()
orbital_period_numpy(a)
end_time = time.time()
print("NumPy function time:", end_time - start_time, "seconds")

# Timing the original function
start_time = time.time()
orbital_period_basic(a)
end_time = time.time()
print("Original function time:", end_time - start_time, "seconds")

# Create a list with 1,000,000 semi-major axis values
semi_major_axes = [i * 0.1 for i in range(1, 1000001)]
# Out:
# NumPy function time: 0.0002028942108154297 seconds
# Original function time: 0.000614166259765625 seconds

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# NumPy is faster because it’s made for math operations. It works better with large amounts of data.

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

# Loop to filter and print radii of planets with temperatures below 350 K
for radius, temp in zip(radii, temperatures):
    if temp < 350:
        print(radius)
# Out:
# 1.2
# 2.0

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]

# List slicing 
first_three_radii = radii[:3]

# Print
print(first_three_radii)
# Out:
# [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

# Dictionary
planet_data = dict(zip(radii, temperatures))

# Print
print(planet_data)
# Out:
# {1.2: 300, 0.8: 400, 1.5: 350, 2.0: 280, 1.0: 500, 0.6: 450}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

# Planet names
planet_names = ["P1", "P2", "P3", "P4", "P5", "P6"]

# Dictonary
planet_data = {name: (radius, temperature) for name, radius, temperature in zip(planet_names, radii, temperatures)}

# Print
print(planet_data)
# Out:
# {'P1': (1.2, 300), 'P2': (0.8, 400), 'P3': (1.5, 350), 'P4': (2.0, 280), 'P5': (1.0, 500), 'P6': (0.6, 450)}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

# Planet names
planet_names = ["P1", "P2", "P3", "P4", "P5", "P6"]

# Dictionary with planets having radii between 1.0 and 2.0
inclusive_planet_data = {name: (radius, temperature) for name, radius, temperature in zip(planet_names, radii, temperatures) if 1.0 <= radius <= 2.0}

# Print the filtered dictionary
print(inclusive_planet_data)
# Out:
# {'P1': (1.2, 300), 'P3': (1.5, 350), 'P4': (2.0, 280), 'P5': (1.0, 500)}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
import numpy as np

# Convert the list to a NumPy array
semi_major_axes_array = np.array([i * 0.1 for i in range(1, 1000001)])

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
import numpy as np

# Convert the list to a NumPy array
semi_major_axes_array = np.array([i * 0.1 for i in range(1, 1000001)])

# Calculate the mean, median, minimum, and maximum
mean = np.mean(semi_major_axes_array)
median = np.median(semi_major_axes_array)
minimum = np.min(semi_major_axes_array)
maximum = np.max(semi_major_axes_array)

# Print the results
print("Mean:", mean)
print("Median:", median)
print("Minimum:", minimum)
print("Maximum:", maximum)
# Out:
# Mean: 50000.05
# Median: 50000.05
# Minimum: 0.1
# Maximum: 100000.0

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
import numpy as np

# Convert the list to a NumPy array
semi_major_axes_array = np.array([i * 0.1 for i in range(1, 1000001)])

# Calculate the variance
variance = np.var(semi_major_axes_array)

# Print the result
print("Variance:", variance)
# Variance quantifies how much the data points deviate from the mean on average. A higher variance means the data points are more spread out, and a lower variance means they are closer to the mean.
# Out:
# Variance: 833333333.3325001

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
import numpy as np

# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

# Combine radii + temperatures into a 2D array
planet_data_array = np.array([radii, temperatures]).T 

# Print
print(planet_data_array)
# Out:
# [[  1.2 300. ]
#  [  0.8 400. ]
#  [  1.5 350. ]
#  [  2.  280. ]
#  [  1.  500. ]
#  [  0.6 450. ]]

# %% [markdown]
# Use a for loop to print the value on the second row, second column.

# %%
import numpy as np

# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

# Combine radii + temperatures into a 2D array
planet_data_array = np.array([radii, temperatures]).T 

# Print the value in the second row, second column
for i, row in enumerate(planet_data_array):
    if i == 1:  # Second row (index 1)
        print(row[1])  # Second column (index 1)
# Out:
# 400.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, second column.

# %%
import numpy as np

# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

# Combine radii + temperatures into a 2D array
planet_data_array = np.array([radii, temperatures]).T 

# Print
print(planet_data_array[1, 1])
# Out:
# 400.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
import matplotlib.pyplot as plt
import numpy as np

# Given semi-major axes
semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]

# Oribtal periods using Kepler's
orbital_periods = [np.sqrt(a ** 3) for a in semi_major_axes]

# Scatter plot
plt.scatter(semi_major_axes, orbital_periods, label='Orbital Period')

# Label the axes
plt.xlabel('Semi-Major Axis (AU)')
plt.ylabel('Orbital Period (Yrs)')

# Title
plt.title('Orbital Periods of Exoplanets')

# Legend
plt.legend()

# Print
plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
import matplotlib.pyplot as plt

# Given data
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
planet_names = ["P1", "P2", "P3", "P4", "P5", "P6"]

# Bar plot
plt.bar(planet_names, temperatures, label='Temperature', color='pink')

# Label
plt.xlabel('Planet')
plt.ylabel('Equilibrium Temperature (K)')

# Title
plt.title('Equilibrium Temperatures vs. Radii')

# Legend
plt.legend()

# Print
plt.show()

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
import matplotlib.pyplot as plt
import numpy as np

# Given data
semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
planet_names = ["P1", "P2", "P3", "P4", "P5", "P6"]

# Orbital periods using Kepler's 
orbital_periods = [np.sqrt(a ** 3) for a in semi_major_axes]

# Scatter plot and bar plot on the same figure
plt.figure(figsize=(20, 10))

# Scatter plot 
plt.subplot(1, 2, 1)  
plt.scatter(semi_major_axes, orbital_periods, label='Orbital Period')
plt.xlabel('Semi-Major Axis (AU)')
plt.ylabel('Orbital Period (Years)')
plt.title('Orbital Periods of Exoplanets')
plt.legend()

# Bar plot
plt.subplot(1, 2, 2) 
plt.bar(planet_names, temperatures, label='Temperature', color='pink')
plt.xlabel('Planet')
plt.ylabel('Equilibrium Temperature (K)')
plt.title('Equilibrium Temperatures vs. Radii')
plt.legend()

# Print
plt.show()

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.
